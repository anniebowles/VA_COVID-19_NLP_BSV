# %%
#check that the notebook is pointing to your anaconda version, not the master Anaconda folder
#import sys
#sys.path

# %% [markdown]
# ## A note on adjusting the rules
# You have to restart the kernel and re-import the libraries every time you add rules to the knowledge_base files.

# %%
import medspacy
import spacy
import cov_bsv
#from cov_bsv import visualize_doc
from medspacy.visualization import visualize_ent
from medspacy.ner import TargetMatcher, TargetRule
from spacy import displacy

import warnings
warnings.filterwarnings("ignore")

# %%
with open("O:\\VINCI_COVIDNLP\\va_external_c19_tests\\examples\\text_4.txt", 'r') as reader:
    text = reader.read()

print(type(text))
#print(text)
# Out:
# <class 'str'>

# %% [markdown]
# ## Sections

# %%
nlp = cov_bsv.load(enable=["tagger", "parser", "concept_tagger", "target_matcher", "sectionizer"])

# %%
doc = nlp(text)

# %%
visualize_ent(doc)
#visualize_dep(doc)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID FOLLOW UP TELEPHONE NOTE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< COVID_TELEPHONE_NOTE >></span>
# </mark>
#  </br></br>Were you able to contact patient by phone?</br>  Yes</br>
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patient COVID-19 test results:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< OUTSIDE_COVID_LABS >></span>
# </mark>
#
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  test results:</br>      Not detected</br>
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Where was the test performed?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< COVID_QUESTION >></span>
# </mark>
#
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VA
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# When?
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apr 26,2020
#
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Talked to the Veteran
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  regarding Negative results.  He stated that he was </br>already called and informed.  He does not have any symptoms, but was tested </br>becuase he was exposed from a positive family member through a grandbaby. He </br>understands that he still needs to maintain social isolation. </br></br>
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Documentation of outside COVID-19 information
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< OUTSIDE_COVID_LABS >></span>
# </mark>
#
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  information.</br>
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#
# <mark class="entity" style="background: #e377c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Outside Test Results
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EXTERNAL_LOCATION</span>
# </mark>
#  POSITIVE</br>
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Date:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< DATE >></span>
# </mark>
#
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 7, 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Location:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< LOCATION >></span>
# </mark>
#
# <mark class="entity" style="background: #e377c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Non-VA Site
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EXTERNAL_LOCATION</span>
# </mark>
# </br>    Comment: Symptomatic veteran presented in
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ED
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  stating positive
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
# </br>    test result. Positive result
# <mark class="entity" style="background: #ff7f0e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     confirmed with
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">IGNORE</span>
# </mark>
#
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FL DOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</br>    </br>
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; l

# %%
for ent in doc.ents:
    print(ent)
    print("Uncertain:", ent._.is_uncertain)
    print("Negated:", ent._.is_negated)
    print("Positive:", ent._.is_positive)
    print("Tested outside VA:", ent._.is_external)
    print("Experienced by someone else:", ent._.is_other_experiencer)
    print()
# Out:
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# VA
#
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Apr 26,2020
#
#
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# today
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Outside Test Results
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# April 7, 2020
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Non-VA Site
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# ED
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# confirmed with
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# FL DOH
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# VA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Jordan Valley Hospital
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# MM
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 04/29/20
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# VA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Jordan Valley Hospital
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# MM
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 3
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 2 liters
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# daily
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 195
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# CPRS
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 214
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 2
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# covid positive
# Uncertain: False
# Negated: False
# Positive: True
# Tested outside VA: False
# Experienced by someone else: False
#
# tonight
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# tomorrow
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Day 9
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# covid
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# today
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 3 min
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 8 min
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 11 min
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# VA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# McKay Dee Hospital
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# MM
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# VA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# McKay Dee Hospital
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# MM
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# NCM
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# every day
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# this week
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# next week
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# PCP
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# years
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# PCP
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Negative
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19 PCR Lab test
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# a
# location other than this VA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# April 29, 2020
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# May 1, 2020
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Lake Elsinore Diamond Stadium Drive-Thru
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Elsinore
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 945-6171
#
#
#
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# two
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Day five
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# PCP
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# today
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Today
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# DRMCH
#
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID 19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID19-Not
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Mook
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# DOMBECK
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# TARA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 10
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Apr 2020
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Coronavirus
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Apr 2020
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Coronavirus
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# NASOPHARYNGEAL
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 2019-NCOV
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Covid-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Coronavirus
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 2019
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19 lab test
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# SVH
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# days
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 10 days
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 4/19/20
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 4/17/20
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# SVH
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 139379984
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Order 139379983
#
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# MyChart
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 08/07/2020
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 01:00 PM
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Family Medicine
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# Nasopharyngeal Swab
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# LabCorp
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# 10:42
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# TOVA
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# SVH
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False
#
# COVID-19
# Uncertain: False
# Negated: False
# Positive: False
# Tested outside VA: False
# Experienced by someone else: False

# %% [markdown]
# ### Example of the difference between the default spaCy and the medspaCy tokenizers

# %%
from medspacy.custom_tokenizer import create_medspacy_tokenizer

nlp = spacy.blank("en")

medspacy_tokenizer = create_medspacy_tokenizer(nlp)
default_tokenizer = nlp.tokenizer

example = r'December(23rd)' #r'Jul 22, 2020' #text[2] #r'10-18-20' #r'Pt c/o n;v;d h/o chf+cp'

print("spacy tokenizer:")
print(list(default_tokenizer(example)))
print('\n')
print("medspacy tokenizer:")
print(list(medspacy_tokenizer(example)))
#for ent in doc.ents:
    #print(ent.text, ent.label_, sep=" -> ")
# Out:
# spacy tokenizer:
# [December(23rd, )]
#
#
# medspacy tokenizer:
# [December, (, 23rd, )]
